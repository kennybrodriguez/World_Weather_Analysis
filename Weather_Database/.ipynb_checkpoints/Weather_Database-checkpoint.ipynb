# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime
import time
from scipy.stats import linregress
import gmaps

#import api key
from config import weather_api_key
from config import g_key

# %%
# Create a list for holding the cities.
cities = []

# Create an empty list to hold the weather data.
city_data = []

#create counters
record_count = 1
set_count = 1

#random set of 2000 lats and long for a random list of 500 cities or more
lats = np.random.uniform(-90,90,size = 2000)
lngs = np.random.uniform(-180,180, size = 2000)
lat_lngs = zip(lats,lngs)

#add the coordinates to a list
coordinates = list(lat_lngs)

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Loop through all the cities in the list.
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | tilichiki
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | teahupoo
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 1 | melo
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | kyenjojo
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | casper
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | cozumel
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | uberaba
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | norsup
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | banjarmasin
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | lesozavodsk
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | milkovo
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | bestobe
# Processing Record 35 of Set 1 | yatou
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | tessalit
# Processing Record 39 of Set 1 | zemen
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | bend
# Processing Record 42 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | minsk
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | baykit
# Processing Record 50 of Set 1 | ancud
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | luderitz
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | resistencia
# Processing Record 8 of Set 2 | motygino
# Processing Record 9 of Set 2 | akyab
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | yar-sale
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 2 | springbok
# Processing Record 18 of Set 2 | coahuayana
# Processing Record 19 of Set 2 | iranshahr
# Processing Record 20 of Set 2 | haapiti
# Processing Record 21 of Set 2 | talikota
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | hennenman
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | daloa
# Processing Record 26 of Set 2 | ola
# Processing Record 27 of Set 2 | alice springs
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | katobu
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | zyryanka
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | makakilo city
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | mwinilunga
# Processing Record 37 of Set 2 | saint-pierre
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | konevo
# Processing Record 41 of Set 2 | hami
# Processing Record 42 of Set 2 | kamaishi
# Processing Record 43 of Set 2 | praxedis guerrero
# Processing Record 44 of Set 2 | san carlos
# Processing Record 45 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | ambovombe
# Processing Record 48 of Set 2 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 49 of Set 2 | shitanjing
# Processing Record 50 of Set 2 | eloy
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | dickinson
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | pizhma
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | xuddur
# Processing Record 10 of Set 3 | mudigere
# Processing Record 11 of Set 3 | kudahuvadhoo
# Processing Record 12 of Set 3 | matir
# City not found. Skipping...
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | kosh-agach
# Processing Record 16 of Set 3 | clyde river
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | praya
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | rognan
# Processing Record 21 of Set 3 | guaruja
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | mata
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | jutai
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | ossora
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | noumea
# Processing Record 33 of Set 3 | goulburn
# Processing Record 34 of Set 3 | booue
# Processing Record 35 of Set 3 | sol-iletsk
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | maragogi
# Processing Record 39 of Set 3 | korop
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | bataipora
# Processing Record 43 of Set 3 | champerico
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | kushmurun
# Processing Record 47 of Set 3 | taltal
# Processing Record 48 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | fairview
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | viareggio
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | ise
# Processing Record 6 of Set 4 | samarai
# Processing Record 7 of Set 4 | general pico
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | richards bay
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | buala
# Processing Record 13 of Set 4 | arrifes
# Processing Record 14 of Set 4 | north platte
# Processing Record 15 of Set 4 | la paz
# Processing Record 16 of Set 4 | tiznit
# Processing Record 17 of Set 4 | tarko-sale
# Processing Record 18 of Set 4 | mareeba
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | uyskoye
# Processing Record 21 of Set 4 | inhambane
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | port lincoln
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | dzhebariki-khaya
# Processing Record 27 of Set 4 | tigil
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | daru
# Processing Record 30 of Set 4 | ust-tsilma
# Processing Record 31 of Set 4 | kiama
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | pizarro
# Processing Record 36 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 4 | port-gentil
# Processing Record 38 of Set 4 | stanger
# Processing Record 39 of Set 4 | fostoria
# Processing Record 40 of Set 4 | baghdad
# Processing Record 41 of Set 4 | sisimiut
# Processing Record 42 of Set 4 | tzucacab
# Processing Record 43 of Set 4 | boyle
# Processing Record 44 of Set 4 | dunnville
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | georgetown
# Processing Record 47 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 50 of Set 4 | half moon bay
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | nara
# Processing Record 3 of Set 5 | talbahat
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | palmer
# Processing Record 7 of Set 5 | lazaro cardenas
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | sabang
# Processing Record 10 of Set 5 | marystown
# Processing Record 11 of Set 5 | tierralta
# Processing Record 12 of Set 5 | peace river
# Processing Record 13 of Set 5 | najran
# Processing Record 14 of Set 5 | matadi
# Processing Record 15 of Set 5 | senica
# Processing Record 16 of Set 5 | kayerkan
# Processing Record 17 of Set 5 | vilyuysk
# Processing Record 18 of Set 5 | tromso
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 5 | gumdag
# Processing Record 25 of Set 5 | port blair
# Processing Record 26 of Set 5 | lively
# Processing Record 27 of Set 5 | monroe
# Processing Record 28 of Set 5 | portland
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | podgornoye
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | mundo nuevo
# Processing Record 35 of Set 5 | harper
# Processing Record 36 of Set 5 | sarangani
# Processing Record 37 of Set 5 | aykhal
# Processing Record 38 of Set 5 | iglino
# Processing Record 39 of Set 5 | flinders
# Processing Record 40 of Set 5 | torbay
# Processing Record 41 of Set 5 | nanyamba
# Processing Record 42 of Set 5 | esso
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | morant bay
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | almeirim
# Processing Record 48 of Set 5 | mayumba
# Processing Record 49 of Set 5 | bom jesus
# Processing Record 50 of Set 5 | kalabo
# Processing Record 1 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | zhigansk
# Processing Record 3 of Set 6 | carballo
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | merauke
# Processing Record 6 of Set 6 | saint-augustin
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | doka
# Processing Record 9 of Set 6 | yekaterinovka
# Processing Record 10 of Set 6 | santa cruz cabralia
# Processing Record 11 of Set 6 | svetlogorsk
# Processing Record 12 of Set 6 | puerto del rosario
# Processing Record 13 of Set 6 | mali
# Processing Record 14 of Set 6 | waingapu
# Processing Record 15 of Set 6 | fukuma
# Processing Record 16 of Set 6 | tinglev
# Processing Record 17 of Set 6 | suoyarvi
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 6 | synya
# Processing Record 21 of Set 6 | beidao
# Processing Record 22 of Set 6 | cap-aux-meules
# Processing Record 23 of Set 6 | qaanaaq
# Processing Record 24 of Set 6 | kemijarvi
# Processing Record 25 of Set 6 | monrovia
# Processing Record 26 of Set 6 | bathsheba
# Processing Record 27 of Set 6 | nouadhibou
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 6 | gorontalo
# Processing Record 32 of Set 6 | tuatapere
# Processing Record 33 of Set 6 | kuching
# Processing Record 34 of Set 6 | kitimat
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | tahta
# Processing Record 38 of Set 6 | mezhova
# Processing Record 39 of Set 6 | pisco
# Processing Record 40 of Set 6 | general roca
# Processing Record 41 of Set 6 | bubaque
# Processing Record 42 of Set 6 | stornoway
# Processing Record 43 of Set 6 | victoria
# Processing Record 44 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 6 | moyale
# Processing Record 46 of Set 6 | kalmunai
# Processing Record 47 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | ayan
# Processing Record 49 of Set 6 | jalu
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | svetlyy
# Processing Record 2 of Set 7 | mankono
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | marrakesh
# Processing Record 5 of Set 7 | atar
# Processing Record 6 of Set 7 | la rochelle
# Processing Record 7 of Set 7 | floro
# Processing Record 8 of Set 7 | campbell river
# Processing Record 9 of Set 7 | ust-maya
# Processing Record 10 of Set 7 | sibut
# Processing Record 11 of Set 7 | ambilobe
# Processing Record 12 of Set 7 | hailar
# Processing Record 13 of Set 7 | thompson
# Processing Record 14 of Set 7 | port elizabeth
# Processing Record 15 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 7 | salinopolis
# Processing Record 17 of Set 7 | kurchum
# Processing Record 18 of Set 7 | delmas
# Processing Record 19 of Set 7 | chicama
# Processing Record 20 of Set 7 | inta
# Processing Record 21 of Set 7 | storslett
# Processing Record 22 of Set 7 | mahon
# Processing Record 23 of Set 7 | ixtapa
# Processing Record 24 of Set 7 | morondava
# Processing Record 25 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 7 | fare
# Processing Record 27 of Set 7 | zhaotong
# Processing Record 28 of Set 7 | kahului
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | asau
# Processing Record 31 of Set 7 | fukue
# Processing Record 32 of Set 7 | tornio
# Processing Record 33 of Set 7 | srednekolymsk
# Processing Record 34 of Set 7 | preeceville
# Processing Record 35 of Set 7 | nhulunbuy
# Processing Record 36 of Set 7 | wewak
# Processing Record 37 of Set 7 | shiyan
# Processing Record 38 of Set 7 | sibolga
# Processing Record 39 of Set 7 | qasigiannguit
# Processing Record 40 of Set 7 | nenjiang
# Processing Record 41 of Set 7 | aswan
# Processing Record 42 of Set 7 | teguise
# Processing Record 43 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 7 | saint-joseph
# Processing Record 45 of Set 7 | vorukh
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | calama
# Processing Record 48 of Set 7 | liverpool
# Processing Record 49 of Set 7 | coihaique
# Processing Record 50 of Set 7 | axim
# Processing Record 1 of Set 8 | malakal
# Processing Record 2 of Set 8 | vestmannaeyjar
# Processing Record 3 of Set 8 | kapuskasing
# Processing Record 4 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 8 | ezhou
# Processing Record 6 of Set 8 | kavieng
# Processing Record 7 of Set 8 | mstera
# Processing Record 8 of Set 8 | port hardy
# Processing Record 9 of Set 8 | kaohsiung
# Processing Record 10 of Set 8 | sao felix do xingu
# Processing Record 11 of Set 8 | sweetwater
# Processing Record 12 of Set 8 | colares
# Processing Record 13 of Set 8 | singaraja
# Processing Record 14 of Set 8 | san rafael
# Processing Record 15 of Set 8 | airai
# Processing Record 16 of Set 8 | villa carlos paz
# Processing Record 17 of Set 8 | west bay
# Processing Record 18 of Set 8 | oxelosund
# Processing Record 19 of Set 8 | kalur kot
# Processing Record 20 of Set 8 | jiuquan
# Processing Record 21 of Set 8 | ravar
# Processing Record 22 of Set 8 | araouane
# Processing Record 23 of Set 8 | itoman
# Processing Record 24 of Set 8 | andrelandia
# Processing Record 25 of Set 8 | bhadasar
# Processing Record 26 of Set 8 | oranjemund
# Processing Record 27 of Set 8 | puerto escondido
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | husavik
# Processing Record 30 of Set 8 | sur
# Processing Record 31 of Set 8 | quebo
# Processing Record 32 of Set 8 | akropong
# Processing Record 33 of Set 8 | severo-kurilsk
# Processing Record 34 of Set 8 | chingirlau
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | xingtai
# Processing Record 37 of Set 8 | cap malheureux
# Processing Record 38 of Set 8 | brownwood
# Processing Record 39 of Set 8 | constitucion
# Processing Record 40 of Set 8 | bacolod
# Processing Record 41 of Set 8 | kruisfontein
# Processing Record 42 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 8 | pokhara
# Processing Record 44 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | gasa
# Processing Record 46 of Set 8 | tete
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | santa rosa
# Processing Record 49 of Set 8 | redlands
# Processing Record 50 of Set 8 | hopelchen
# Processing Record 1 of Set 9 | nuevo progreso
# Processing Record 2 of Set 9 | atocha
# Processing Record 3 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 9 | nagua
# Processing Record 5 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 7 of Set 9 | viedma
# Processing Record 8 of Set 9 | okhotsk
# Processing Record 9 of Set 9 | nikolskoye
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | salcininkai
# Processing Record 12 of Set 9 | cockburn town
# Processing Record 13 of Set 9 | hualmay
# Processing Record 14 of Set 9 | te anau
# Processing Record 15 of Set 9 | walvis bay
# Processing Record 16 of Set 9 | ambanja
# Processing Record 17 of Set 9 | ciudad bolivar
# Processing Record 18 of Set 9 | goure
# Processing Record 19 of Set 9 | popondetta
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | venado tuerto
# Processing Record 22 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | caravelas
# Processing Record 25 of Set 9 | qandala
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | khovu-aksy
# Processing Record 28 of Set 9 | el sauzal
# Processing Record 29 of Set 9 | cabo san lucas
# Processing Record 30 of Set 9 | cha grande
# Processing Record 31 of Set 9 | lulea
# Processing Record 32 of Set 9 | quatre cocos
# Processing Record 33 of Set 9 | oussouye
# Processing Record 34 of Set 9 | soubre
# Processing Record 35 of Set 9 | haines junction
# Processing Record 36 of Set 9 | yeppoon
# Processing Record 37 of Set 9 | beipiao
# Processing Record 38 of Set 9 | kempele
# Processing Record 39 of Set 9 | chumikan
# Processing Record 40 of Set 9 | vila
# Processing Record 41 of Set 9 | ewa beach
# Processing Record 42 of Set 9 | vanimo
# Processing Record 43 of Set 9 | yaan
# Processing Record 44 of Set 9 | davidson
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | fianga
# City not found. Skipping...
# Processing Record 47 of Set 9 | kloulklubed
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | vila franca do campo
# Processing Record 50 of Set 9 | madhipura
# Processing Record 1 of Set 10 | lucea
# Processing Record 2 of Set 10 | kubuta
# Processing Record 3 of Set 10 | ayr
# Processing Record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 10 | isaszeg
# Processing Record 6 of Set 10 | kazanskoye
# Processing Record 7 of Set 10 | selenduma
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | quelimane
# Processing Record 11 of Set 10 | sawtell
# Processing Record 12 of Set 10 | cabra
# Processing Record 13 of Set 10 | alenquer
# Processing Record 14 of Set 10 | umm kaddadah
# Processing Record 15 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 10 | kungurtug
# Processing Record 17 of Set 10 | kitchener
# Processing Record 18 of Set 10 | broken hill
# Processing Record 19 of Set 10 | katsuura
# Processing Record 20 of Set 10 | damortis
# Processing Record 21 of Set 10 | amapa
# Processing Record 22 of Set 10 | bowen
# Processing Record 23 of Set 10 | salalah
# Processing Record 24 of Set 10 | ilinskiy
# Processing Record 25 of Set 10 | pangai
# Processing Record 26 of Set 10 | selenginsk
# Processing Record 27 of Set 10 | dong hoi
# Processing Record 28 of Set 10 | oistins
# Processing Record 29 of Set 10 | thio
# Processing Record 30 of Set 10 | north bend
# Processing Record 31 of Set 10 | kapit
# Processing Record 32 of Set 10 | ziro
# Processing Record 33 of Set 10 | sinnamary
# Processing Record 34 of Set 10 | keti bandar
# Processing Record 35 of Set 10 | lasa
# Processing Record 36 of Set 10 | uige
# Processing Record 37 of Set 10 | nome
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 10 | beba
# Processing Record 41 of Set 10 | bar harbor
# Processing Record 42 of Set 10 | narasannapeta
# Processing Record 43 of Set 10 | lompoc
# Processing Record 44 of Set 10 | cortez
# Processing Record 45 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 46 of Set 10 | joshimath
# Processing Record 47 of Set 10 | luganville
# Processing Record 48 of Set 10 | chkalovskoye
# Processing Record 49 of Set 10 | agen
# Processing Record 50 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 1 of Set 11 | havoysund
# Processing Record 2 of Set 11 | saurimo
# Processing Record 3 of Set 11 | pangoa
# Processing Record 4 of Set 11 | zhigalovo
# Processing Record 5 of Set 11 | port moresby
# Processing Record 6 of Set 11 | bandarbeyla
# Processing Record 7 of Set 11 | sao joao da barra
# Processing Record 8 of Set 11 | dwarka
# Processing Record 9 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 11 | severnyy
# Processing Record 11 of Set 11 | tambacounda
# Processing Record 12 of Set 11 | haywards heath
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | mercedes
# Processing Record 15 of Set 11 | conceicao da barra
# Processing Record 16 of Set 11 | biltine
# Processing Record 17 of Set 11 | hamilton
# Processing Record 18 of Set 11 | waipawa
# Processing Record 19 of Set 11 | cururupu
# Processing Record 20 of Set 11 | shingu
# Processing Record 21 of Set 11 | tabuk
# Processing Record 22 of Set 11 | kabo
# Processing Record 23 of Set 11 | dali
# Processing Record 24 of Set 11 | privolzhye
# Processing Record 25 of Set 11 | baherden
# Processing Record 26 of Set 11 | lagos
# Processing Record 27 of Set 11 | zambrow
# Processing Record 28 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 29 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 11 | aden
# Processing Record 31 of Set 11 | alma
# Processing Record 32 of Set 11 | amberieu-en-bugey
# Processing Record 33 of Set 11 | ulladulla
# Processing Record 34 of Set 11 | tecpan
# Processing Record 35 of Set 11 | taitung
# Processing Record 36 of Set 11 | palatka
# Processing Record 37 of Set 11 | pyapon
# Processing Record 38 of Set 11 | ichinoseki
# Processing Record 39 of Set 11 | hermosillo
# Processing Record 40 of Set 11 | lisakovsk
# Processing Record 41 of Set 11 | oksfjord
# Processing Record 42 of Set 11 | tual
# Processing Record 43 of Set 11 | cardston
# Processing Record 44 of Set 11 | vila velha
# Processing Record 45 of Set 11 | ponta delgada
# Processing Record 46 of Set 11 | solnechnyy
# Processing Record 47 of Set 11 | khilchipur
# Processing Record 48 of Set 11 | tubmanburg
# Processing Record 49 of Set 11 | les cayes
# Processing Record 50 of Set 11 | lakatoro
# Processing Record 1 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 12 | kendari
# Processing Record 3 of Set 12 | altay
# Processing Record 4 of Set 12 | winslow
# Processing Record 5 of Set 12 | ahipara
# Processing Record 6 of Set 12 | buraydah
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | capitan bado
# Processing Record 9 of Set 12 | honningsvag
# Processing Record 10 of Set 12 | nishihara
# Processing Record 11 of Set 12 | ballina
# Processing Record 12 of Set 12 | mineral wells
# Processing Record 13 of Set 12 | rondonopolis
# Processing Record 14 of Set 12 | nguruka
# Processing Record 15 of Set 12 | uzhur
# Processing Record 16 of Set 12 | aitape
# Processing Record 17 of Set 12 | saint petersburg
# Processing Record 18 of Set 12 | mehamn
# Processing Record 19 of Set 12 | verkhoyansk
# Processing Record 20 of Set 12 | bilma
# Processing Record 21 of Set 12 | keroka
# Processing Record 22 of Set 12 | asfi
# Processing Record 23 of Set 12 | dunmore town
# Processing Record 24 of Set 12 | ginda
# Processing Record 25 of Set 12 | havelock
# Processing Record 26 of Set 12 | urumqi
# Processing Record 27 of Set 12 | omsukchan
# Processing Record 28 of Set 12 | along
# Processing Record 29 of Set 12 | monticello
# Processing Record 30 of Set 12 | moroni
# Processing Record 31 of Set 12 | aracoiaba
# Processing Record 32 of Set 12 | russell
# Processing Record 33 of Set 12 | fairbanks
# Processing Record 34 of Set 12 | saint-denis
# Processing Record 35 of Set 12 | smolenka
# Processing Record 36 of Set 12 | vao
# Processing Record 37 of Set 12 | phu ly
# Processing Record 38 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 12 | la peca
# Processing Record 40 of Set 12 | wakkanai
# Processing Record 41 of Set 12 | shambu
# Processing Record 42 of Set 12 | tongling
# Processing Record 43 of Set 12 | kawalu
# Processing Record 44 of Set 12 | tura
# Processing Record 45 of Set 12 | ituporanga
# Processing Record 46 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 12 | crotone
# Processing Record 48 of Set 12 | carolina
# Processing Record 49 of Set 12 | dalvik
# Processing Record 50 of Set 12 | guapo
# Processing Record 1 of Set 13 | porto nacional
# Processing Record 2 of Set 13 | odemira
# Processing Record 3 of Set 13 | itaituba
# Processing Record 4 of Set 13 | broome
# Processing Record 5 of Set 13 | finnsnes
# Processing Record 6 of Set 13 | desnogorsk
# Processing Record 7 of Set 13 | rio grande
# Processing Record 8 of Set 13 | garissa
# Processing Record 9 of Set 13 | mahibadhoo
# Processing Record 10 of Set 13 | pando
# Processing Record 11 of Set 13 | maldonado
# Processing Record 12 of Set 13 | homer
# Processing Record 13 of Set 13 | samana
# Processing Record 14 of Set 13 | tubigan
# Processing Record 15 of Set 13 | borborema
# Processing Record 16 of Set 13 | novodolinskiy
# Processing Record 17 of Set 13 | kerema
# Processing Record 18 of Set 13 | la sarre
# Processing Record 19 of Set 13 | atbasar
# Processing Record 20 of Set 13 | matara
# Processing Record 21 of Set 13 | leninsk
# Processing Record 22 of Set 13 | rosarito
# Processing Record 23 of Set 13 | areka
# Processing Record 24 of Set 13 | korla
# Processing Record 25 of Set 13 | grindavik
# Processing Record 26 of Set 13 | qaqortoq
# Processing Record 27 of Set 13 | chamonix-mont-blanc
# Processing Record 28 of Set 13 | neyvo-shaytanskiy
# Processing Record 29 of Set 13 | inirida
# Processing Record 30 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 13 | presidencia roque saenz pena
# Processing Record 32 of Set 13 | bushehr
# Processing Record 33 of Set 13 | ust-nera
# Processing Record 34 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 35 of Set 13 | tungor
# Processing Record 36 of Set 13 | ekibastuz
# Processing Record 37 of Set 13 | vestmanna
# Processing Record 38 of Set 13 | manzhouli
# Processing Record 39 of Set 13 | ormara
# Processing Record 40 of Set 13 | kinston
# Processing Record 41 of Set 13 | tapes
# Processing Record 42 of Set 13 | vuktyl
# Processing Record 43 of Set 13 | dzilam gonzalez
# Processing Record 44 of Set 13 | belmonte
# Processing Record 45 of Set 13 | auki
# Processing Record 46 of Set 13 | aripuana
# Processing Record 47 of Set 13 | mount pleasant
# Processing Record 48 of Set 13 | grandview
# Processing Record 49 of Set 13 | quang ngai
# Processing Record 50 of Set 13 | methoni
# Processing Record 1 of Set 14 | vanavara
# Processing Record 2 of Set 14 | rabaul
# Processing Record 3 of Set 14 | jackson
# Processing Record 4 of Set 14 | turbat
# Processing Record 5 of Set 14 | salta
# Processing Record 6 of Set 14 | guthrie
# Processing Record 7 of Set 14 | bria
# Processing Record 8 of Set 14 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 9 of Set 14 | rocha
# Processing Record 10 of Set 14 | rio gallegos
# Processing Record 11 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 12 of Set 14 | socorro
# Processing Record 13 of Set 14 | hurghada
# Processing Record 14 of Set 14 | imbituba
# Processing Record 15 of Set 14 | karasburg
# Processing Record 16 of Set 14 | rumuruti
# Processing Record 17 of Set 14 | sterling
# Processing Record 18 of Set 14 | zhangye
# Processing Record 19 of Set 14 | houma
# Processing Record 20 of Set 14 | margate
# Processing Record 21 of Set 14 | san julian
# Processing Record 22 of Set 14 | mackay
# Processing Record 23 of Set 14 | nyimba
# Processing Record 24 of Set 14 | mengcheng
# Processing Record 25 of Set 14 | dingle
# Processing Record 26 of Set 14 | loandjili
# Processing Record 27 of Set 14 | luhyny
# Processing Record 28 of Set 14 | lincoln
# Processing Record 29 of Set 14 | santiago
# Processing Record 30 of Set 14 | manali
# Processing Record 31 of Set 14 | kautokeino
# Processing Record 32 of Set 14 | namur
# Processing Record 33 of Set 14 | seguela
# Processing Record 34 of Set 14 | nadvoitsy
# Processing Record 35 of Set 14 | harpalpur
# Processing Record 36 of Set 14 | soller
# Processing Record 37 of Set 14 | palestina
# Processing Record 38 of Set 14 | yuancheng
# Processing Record 39 of Set 14 | nasice
# Processing Record 40 of Set 14 | minab
# Processing Record 41 of Set 14 | jibuti
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | panacan
# Processing Record 44 of Set 14 | road town
# Processing Record 45 of Set 14 | mlonggo
# Processing Record 46 of Set 14 | belyy yar
# Processing Record 47 of Set 14 | bontang
# Processing Record 48 of Set 14 | goderich
# Processing Record 49 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 14 | whitehorse
# Processing Record 1 of Set 15 | carauari
# Processing Record 2 of Set 15 | sirsa
# Processing Record 3 of Set 15 | touros
# Processing Record 4 of Set 15 | preobrazheniye
# Processing Record 5 of Set 15 | kyabe
# Processing Record 6 of Set 15 | launceston
# Processing Record 7 of Set 15 | itzican
# City not found. Skipping...
# Processing Record 8 of Set 15 | lujan
# Processing Record 9 of Set 15 | jumla
# Processing Record 10 of Set 15 | uchaly
# Processing Record 11 of Set 15 | honiara
# Processing Record 12 of Set 15 | ornskoldsvik
# Processing Record 13 of Set 15 | gornoye loo
# Processing Record 14 of Set 15 | lewiston
# Processing Record 15 of Set 15 | khani
# Processing Record 16 of Set 15 | caucaia
# Processing Record 17 of Set 15 | guajara-mirim
# City not found. Skipping...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Create the output file (CSV).
output_data_file = "Vacation_search/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
