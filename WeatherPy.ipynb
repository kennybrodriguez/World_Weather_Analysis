# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime
import time

#import api key
from config import weather_api_key

# %%
# Create a list for holding the cities.
cities = []

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1

#random set of 1500 lats and long for a random list of 500 cities or more
lats = np.random.uniform(-90,90,size = 1500)
lngs = np.random.uniform(-180,180, size = 1500)
lat_lngs = zip(lats,lngs)

#add the coordinates to a list
coordinates = list(lat_lngs)

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# Beginning Data Retrieval
# -----------------------------
# 623

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | laguna
# Processing Record 3 of Set 1 | bako
# Processing Record 4 of Set 1 | adre
# Processing Record 5 of Set 1 | sao felix do xingu
# Processing Record 6 of Set 1 | sumter
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | puerto madero
# Processing Record 9 of Set 1 | lakhdenpokhya
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | shitanjing
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | eidsvag
# Processing Record 15 of Set 1 | aksu
# Processing Record 16 of Set 1 | castanos
# Processing Record 17 of Set 1 | ye
# City not found. Skipping...
# Processing Record 18 of Set 1 | san cristobal
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | asfi
# Processing Record 22 of Set 1 | kavieng
# Processing Record 23 of Set 1 | barabinsk
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | russell
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | jucurutu
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | blora
# Processing Record 39 of Set 1 | yumen
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | muros
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | karaman
# Processing Record 49 of Set 1 | kibre mengist
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | pangnirtung
# Processing Record 2 of Set 2 | garden city
# Processing Record 3 of Set 2 | uvat
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | sumbe
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | gravdal
# Processing Record 8 of Set 2 | koslan
# Processing Record 9 of Set 2 | saint-leu
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | husavik
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | kyabram
# Processing Record 21 of Set 2 | moerai
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | seoul
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | povenets
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 2 | yar-sale
# Processing Record 34 of Set 2 | rodeo
# Processing Record 35 of Set 2 | northam
# Processing Record 36 of Set 2 | tucumcari
# Processing Record 37 of Set 2 | phnum penh
# City not found. Skipping...
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | iquique
# Processing Record 41 of Set 2 | hesla
# Processing Record 42 of Set 2 | sadon
# Processing Record 43 of Set 2 | noumea
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | grong
# Processing Record 46 of Set 2 | shahkot
# Processing Record 47 of Set 2 | sao joao da barra
# Processing Record 48 of Set 2 | cooma
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | dolores
# Processing Record 2 of Set 3 | padang
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 3 | marsabit
# Processing Record 6 of Set 3 | chokwe
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | mount gambier
# Processing Record 9 of Set 3 | kokoda
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | port lincoln
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | cap malheureux
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | sawtell
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | abonnema
# Processing Record 18 of Set 3 | reconquista
# Processing Record 19 of Set 3 | chicama
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | bang mun nak
# Processing Record 24 of Set 3 | krasnoselkup
# Processing Record 25 of Set 3 | muncar
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | nemuro
# Processing Record 28 of Set 3 | haines junction
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | sechura
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | wajima
# Processing Record 33 of Set 3 | vao
# Processing Record 34 of Set 3 | leeuwarden
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | imbituba
# Processing Record 39 of Set 3 | coihaique
# Processing Record 40 of Set 3 | moose factory
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | matay
# Processing Record 43 of Set 3 | tucuman
# Processing Record 44 of Set 3 | bandarbeyla
# Processing Record 45 of Set 3 | fortuna
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | bagdarin
# Processing Record 48 of Set 3 | lagoa
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | sambava
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | caborca
# Processing Record 3 of Set 4 | havoysund
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | saint anthony
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | tura
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | hami
# Processing Record 13 of Set 4 | fort saint james
# Processing Record 14 of Set 4 | faxinal
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | izhma
# Processing Record 20 of Set 4 | matara
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | rundu
# Processing Record 23 of Set 4 | yei
# Processing Record 24 of Set 4 | paamiut
# Processing Record 25 of Set 4 | meadow lake
# Processing Record 26 of Set 4 | kuhdasht
# Processing Record 27 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 4 | aswan
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | jaque
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 33 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 4 | shache
# Processing Record 35 of Set 4 | boralday
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | shakiso
# Processing Record 39 of Set 4 | barra patuca
# Processing Record 40 of Set 4 | porangatu
# Processing Record 41 of Set 4 | bredasdorp
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | ketchikan
# Processing Record 44 of Set 4 | santa lucia
# Processing Record 45 of Set 4 | presidencia roque saenz pena
# Processing Record 46 of Set 4 | saint-philippe
# Processing Record 47 of Set 4 | santa rosa
# Processing Record 48 of Set 4 | severo-kurilsk
# Processing Record 49 of Set 4 | moctezuma
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | mier
# Processing Record 2 of Set 5 | viedma
# Processing Record 3 of Set 5 | grand gaube
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | mehamn
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | nyurba
# Processing Record 8 of Set 5 | along
# Processing Record 9 of Set 5 | komsomolskiy
# Processing Record 10 of Set 5 | kysyl-syr
# Processing Record 11 of Set 5 | iskateley
# Processing Record 12 of Set 5 | brooks
# Processing Record 13 of Set 5 | rio bueno
# Processing Record 14 of Set 5 | bireun
# Processing Record 15 of Set 5 | at-bashi
# Processing Record 16 of Set 5 | quang ngai
# Processing Record 17 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 5 | vanavara
# Processing Record 19 of Set 5 | aldan
# Processing Record 20 of Set 5 | thinadhoo
# Processing Record 21 of Set 5 | paramonga
# Processing Record 22 of Set 5 | khagrachari
# City not found. Skipping...
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | kushmurun
# Processing Record 26 of Set 5 | tezu
# Processing Record 27 of Set 5 | escanaba
# Processing Record 28 of Set 5 | kalmunai
# Processing Record 29 of Set 5 | cauquenes
# Processing Record 30 of Set 5 | barrow
# Processing Record 31 of Set 5 | sao miguel
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | ekhabi
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | casper
# Processing Record 38 of Set 5 | tadine
# Processing Record 39 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 5 | kaduqli
# Processing Record 41 of Set 5 | abu samrah
# Processing Record 42 of Set 5 | batagay
# Processing Record 43 of Set 5 | merauke
# Processing Record 44 of Set 5 | lazaro cardenas
# Processing Record 45 of Set 5 | nalut
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | dale
# Processing Record 48 of Set 5 | fomboni
# Processing Record 49 of Set 5 | przhevalskoye
# Processing Record 50 of Set 5 | isla mujeres
# Processing Record 1 of Set 6 | kuching
# Processing Record 2 of Set 6 | pachino
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | akhisar
# Processing Record 5 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 6 | bay roberts
# Processing Record 7 of Set 6 | alice springs
# Processing Record 8 of Set 6 | martapura
# Processing Record 9 of Set 6 | homer
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | hamilton
# Processing Record 12 of Set 6 | bezhetsk
# Processing Record 13 of Set 6 | jizan
# Processing Record 14 of Set 6 | santiago del estero
# Processing Record 15 of Set 6 | norman wells
# Processing Record 16 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 6 | tessaoua
# Processing Record 18 of Set 6 | pacific grove
# Processing Record 19 of Set 6 | ivanava
# Processing Record 20 of Set 6 | harrogate
# Processing Record 21 of Set 6 | namatanai
# Processing Record 22 of Set 6 | batemans bay
# Processing Record 23 of Set 6 | port blair
# Processing Record 24 of Set 6 | bonthe
# Processing Record 25 of Set 6 | kirkwall
# Processing Record 26 of Set 6 | saint-augustin
# Processing Record 27 of Set 6 | pozo colorado
# Processing Record 28 of Set 6 | nago
# Processing Record 29 of Set 6 | ipixuna
# Processing Record 30 of Set 6 | wonthaggi
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | shar
# Processing Record 33 of Set 6 | oistins
# Processing Record 34 of Set 6 | chalon-sur-saone
# Processing Record 35 of Set 6 | conceicao do araguaia
# Processing Record 36 of Set 6 | kurikka
# Processing Record 37 of Set 6 | lumberton
# Processing Record 38 of Set 6 | esteli
# Processing Record 39 of Set 6 | upernavik
# Processing Record 40 of Set 6 | suez
# Processing Record 41 of Set 6 | kingston
# Processing Record 42 of Set 6 | oktyabrskoye
# Processing Record 43 of Set 6 | necochea
# Processing Record 44 of Set 6 | stokmarknes
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | bria
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | ferrol
# Processing Record 49 of Set 6 | kano
# Processing Record 50 of Set 6 | taranto
# Processing Record 1 of Set 7 | belaya gora
# Processing Record 2 of Set 7 | dikson
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | zhangye
# Processing Record 5 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | dejen
# Processing Record 8 of Set 7 | santa cruz
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | katsuura
# Processing Record 12 of Set 7 | eloszallas
# Processing Record 13 of Set 7 | taoudenni
# Processing Record 14 of Set 7 | fez
# Processing Record 15 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 7 | gamba
# Processing Record 17 of Set 7 | caucaia
# Processing Record 18 of Set 7 | mestec kralove
# Processing Record 19 of Set 7 | semporna
# Processing Record 20 of Set 7 | altay
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | altamira
# Processing Record 23 of Set 7 | booue
# Processing Record 24 of Set 7 | berdigestyakh
# Processing Record 25 of Set 7 | krasnoborsk
# Processing Record 26 of Set 7 | sorong
# Processing Record 27 of Set 7 | churapcha
# Processing Record 28 of Set 7 | ust-ilimsk
# Processing Record 29 of Set 7 | utica
# Processing Record 30 of Set 7 | aberystwyth
# Processing Record 31 of Set 7 | jinchang
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | porbandar
# Processing Record 34 of Set 7 | zhuanghe
# Processing Record 35 of Set 7 | zhoucheng
# Processing Record 36 of Set 7 | guerande
# Processing Record 37 of Set 7 | liberal
# Processing Record 38 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 7 | saint-joseph
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | midleton
# Processing Record 42 of Set 7 | santa isabel do rio negro
# Processing Record 43 of Set 7 | la palma
# Processing Record 44 of Set 7 | ponta delgada
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | nizhniy baskunchak
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | bowen
# Processing Record 49 of Set 7 | svetlyy
# Processing Record 50 of Set 7 | severomuysk
# Processing Record 1 of Set 8 | port hawkesbury
# Processing Record 2 of Set 8 | khorixas
# Processing Record 3 of Set 8 | rabak
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | montague
# Processing Record 6 of Set 8 | tharad
# Processing Record 7 of Set 8 | avera
# Processing Record 8 of Set 8 | mareeba
# Processing Record 9 of Set 8 | mahanoro
# Processing Record 10 of Set 8 | richards bay
# Processing Record 11 of Set 8 | dawlatabad
# Processing Record 12 of Set 8 | jaru
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | marzuq
# Processing Record 15 of Set 8 | ponta do sol
# Processing Record 16 of Set 8 | axixa do tocantins
# City not found. Skipping...
# Processing Record 17 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 18 of Set 8 | dhidhdhoo
# Processing Record 19 of Set 8 | torbay
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | comodoro rivadavia
# Processing Record 22 of Set 8 | shetpe
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | smithers
# Processing Record 25 of Set 8 | bologoye
# Processing Record 26 of Set 8 | riohacha
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | luanda
# Processing Record 30 of Set 8 | wanning
# Processing Record 31 of Set 8 | poum
# Processing Record 32 of Set 8 | atasu
# Processing Record 33 of Set 8 | akhnur
# Processing Record 34 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 8 | camacha
# Processing Record 36 of Set 8 | mokhsogollokh
# Processing Record 37 of Set 8 | aleksandrov gay
# Processing Record 38 of Set 8 | rajapur
# Processing Record 39 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 8 | vilyuysk
# Processing Record 41 of Set 8 | trofors
# Processing Record 42 of Set 8 | raduzhnyy
# Processing Record 43 of Set 8 | peto
# Processing Record 44 of Set 8 | lohja
# Processing Record 45 of Set 8 | carmaux
# Processing Record 46 of Set 8 | pangai
# Processing Record 47 of Set 8 | buena vista
# Processing Record 48 of Set 8 | leningradskiy
# Processing Record 49 of Set 8 | ampanihy
# Processing Record 50 of Set 8 | souillac
# Processing Record 1 of Set 9 | carutapera
# Processing Record 2 of Set 9 | wenatchee
# Processing Record 3 of Set 9 | kochubey
# Processing Record 4 of Set 9 | yangjiang
# Processing Record 5 of Set 9 | imeni babushkina
# Processing Record 6 of Set 9 | sur
# Processing Record 7 of Set 9 | kattivakkam
# Processing Record 8 of Set 9 | kiama
# Processing Record 9 of Set 9 | cuamba
# Processing Record 10 of Set 9 | tondano
# Processing Record 11 of Set 9 | ciamis
# Processing Record 12 of Set 9 | flinders
# Processing Record 13 of Set 9 | ancud
# Processing Record 14 of Set 9 | rauma
# Processing Record 15 of Set 9 | high prairie
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | mazatlan
# Processing Record 18 of Set 9 | toora-khem
# Processing Record 19 of Set 9 | songjianghe
# Processing Record 20 of Set 9 | zhiryatino
# Processing Record 21 of Set 9 | hobyo
# Processing Record 22 of Set 9 | trabzon
# Processing Record 23 of Set 9 | vardo
# Processing Record 24 of Set 9 | amontada
# Processing Record 25 of Set 9 | caravelas
# Processing Record 26 of Set 9 | kanlagay
# Processing Record 27 of Set 9 | santarem
# Processing Record 28 of Set 9 | burica
# City not found. Skipping...
# Processing Record 29 of Set 9 | altenholz
# Processing Record 30 of Set 9 | galesong
# Processing Record 31 of Set 9 | puerto carreno
# Processing Record 32 of Set 9 | taseyevo
# Processing Record 33 of Set 9 | zyryanka
# Processing Record 34 of Set 9 | bairiki
# Processing Record 35 of Set 9 | karakol
# Processing Record 36 of Set 9 | fukue
# Processing Record 37 of Set 9 | arica
# Processing Record 38 of Set 9 | quatre cocos
# Processing Record 39 of Set 9 | menomonie
# Processing Record 40 of Set 9 | bonavista
# Processing Record 41 of Set 9 | taos
# Processing Record 42 of Set 9 | kirovskiy
# Processing Record 43 of Set 9 | nishihara
# Processing Record 44 of Set 9 | sola
# Processing Record 45 of Set 9 | luwero
# Processing Record 46 of Set 9 | magog
# Processing Record 47 of Set 9 | coquimbo
# Processing Record 48 of Set 9 | romodanovo
# Processing Record 49 of Set 9 | asau
# Processing Record 50 of Set 9 | lebane
# Processing Record 1 of Set 10 | chaiya
# Processing Record 2 of Set 10 | mahajanga
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | orgita
# Processing Record 5 of Set 10 | kupang
# Processing Record 6 of Set 10 | nizwa
# Processing Record 7 of Set 10 | baykit
# Processing Record 8 of Set 10 | esmeraldas
# Processing Record 9 of Set 10 | sarandi
# Processing Record 10 of Set 10 | belyy yar
# Processing Record 11 of Set 10 | altagracia de orituco
# Processing Record 12 of Set 10 | watertown
# Processing Record 13 of Set 10 | yulara
# Processing Record 14 of Set 10 | olafsvik
# Processing Record 15 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 10 | adeje
# Processing Record 17 of Set 10 | mont-dore
# Processing Record 18 of Set 10 | mayo
# Processing Record 19 of Set 10 | novoagansk
# Processing Record 20 of Set 10 | paradise valley
# Processing Record 21 of Set 10 | alofi
# Processing Record 22 of Set 10 | udachnyy
# Processing Record 23 of Set 10 | melita
# Processing Record 24 of Set 10 | mancio lima
# Processing Record 25 of Set 10 | kaman
# Processing Record 26 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 10 | palu
# Processing Record 28 of Set 10 | gumdag
# Processing Record 29 of Set 10 | okhotsk
# Processing Record 30 of Set 10 | kabare
# Processing Record 31 of Set 10 | puerto colombia
# Processing Record 32 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 10 | kununurra
# Processing Record 34 of Set 10 | rockport
# Processing Record 35 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 10 | comarapa
# Processing Record 37 of Set 10 | kiruna
# Processing Record 38 of Set 10 | tiarei
# Processing Record 39 of Set 10 | beitbridge
# Processing Record 40 of Set 10 | luwuk
# Processing Record 41 of Set 10 | nuuk
# Processing Record 42 of Set 10 | borama
# City not found. Skipping...
# Processing Record 43 of Set 10 | sibut
# Processing Record 44 of Set 10 | linjiang
# Processing Record 45 of Set 10 | te anau
# Processing Record 46 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 10 | ust-maya
# Processing Record 48 of Set 10 | pathein
# Processing Record 49 of Set 10 | cap-aux-meules
# Processing Record 50 of Set 10 | madingou
# Processing Record 1 of Set 11 | srednekolymsk
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | ajdabiya
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 11 | green river
# Processing Record 7 of Set 11 | komarikhinskiy
# Processing Record 8 of Set 11 | chhibramau
# Processing Record 9 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 11 | paka
# Processing Record 11 of Set 11 | lavumisa
# Processing Record 12 of Set 11 | raga
# Processing Record 13 of Set 11 | champasak
# Processing Record 14 of Set 11 | nanzhou
# Processing Record 15 of Set 11 | tangermunde
# Processing Record 16 of Set 11 | tabas
# Processing Record 17 of Set 11 | chapais
# Processing Record 18 of Set 11 | uppsala
# Processing Record 19 of Set 11 | kalino
# Processing Record 20 of Set 11 | dickinson
# Processing Record 21 of Set 11 | ciudad bolivar
# Processing Record 22 of Set 11 | denizli
# Processing Record 23 of Set 11 | kailua
# Processing Record 24 of Set 11 | myitkyina
# Processing Record 25 of Set 11 | grandview
# Processing Record 26 of Set 11 | oranzherei
# Processing Record 27 of Set 11 | meulaboh
# Processing Record 28 of Set 11 | gurupa
# Processing Record 29 of Set 11 | noshiro
# Processing Record 30 of Set 11 | bilibino
# Processing Record 31 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 11 | kouroussa
# Processing Record 33 of Set 11 | mantua
# Processing Record 34 of Set 11 | sioux lookout
# Processing Record 35 of Set 11 | chateauroux
# Processing Record 36 of Set 11 | aykhal
# Processing Record 37 of Set 11 | dauriya
# Processing Record 38 of Set 11 | xichang
# Processing Record 39 of Set 11 | fort-shevchenko
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | butembo
# Processing Record 43 of Set 11 | magadan
# Processing Record 44 of Set 11 | timra
# Processing Record 45 of Set 11 | mumbwa
# Processing Record 46 of Set 11 | caorle
# Processing Record 47 of Set 11 | nyimba
# Processing Record 48 of Set 11 | kidal
# Processing Record 49 of Set 11 | kansanshi
# Processing Record 50 of Set 11 | ojinaga
# Processing Record 1 of Set 12 | kharovsk
# Processing Record 2 of Set 12 | talnakh
# Processing Record 3 of Set 12 | barra do bugres
# Processing Record 4 of Set 12 | alihe
# Processing Record 5 of Set 12 | gigmoto
# Processing Record 6 of Set 12 | zavodskoy
# Processing Record 7 of Set 12 | fairbanks
# Processing Record 8 of Set 12 | bugulma
# Processing Record 9 of Set 12 | bubaque
# Processing Record 10 of Set 12 | la crosse
# Processing Record 11 of Set 12 | sesori
# Processing Record 12 of Set 12 | anadyr
# Processing Record 13 of Set 12 | baruun-urt
# Processing Record 14 of Set 12 | qaqortoq
# Processing Record 15 of Set 12 | kavaratti
# Processing Record 16 of Set 12 | idaho falls
# Processing Record 17 of Set 12 | guaruja
# Processing Record 18 of Set 12 | bay city
# Processing Record 19 of Set 12 | maragogi
# Processing Record 20 of Set 12 | vestmannaeyjar
# Processing Record 21 of Set 12 | zhigansk
# Processing Record 22 of Set 12 | katha
# City not found. Skipping...
# Processing Record 23 of Set 12 | deep river
# Processing Record 24 of Set 12 | nayoro
# Processing Record 25 of Set 12 | banda aceh
# Processing Record 26 of Set 12 | skelleftea
# Processing Record 27 of Set 12 | santa vitoria do palmar
# Processing Record 28 of Set 12 | antsohihy
# Processing Record 29 of Set 12 | ambulu
# Processing Record 30 of Set 12 | rio verde de mato grosso
# Processing Record 31 of Set 12 | turbat
# Processing Record 32 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 12 | beruwala
# Processing Record 34 of Set 12 | gao
# Processing Record 35 of Set 12 | mao
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | nouadhibou
# Processing Record 38 of Set 12 | atbasar
# Processing Record 39 of Set 12 | zeya
# Processing Record 40 of Set 12 | berlevag
# Processing Record 41 of Set 12 | tuatapere
# Processing Record 42 of Set 12 | rio grande
# Processing Record 43 of Set 12 | sudak
# Processing Record 44 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 12 | urazovo
# Processing Record 46 of Set 12 | tahta
# Processing Record 47 of Set 12 | tigil
# Processing Record 48 of Set 12 | zlocieniec
# Processing Record 49 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | idenao
# Processing Record 1 of Set 13 | toluviejo
# Processing Record 2 of Set 13 | muscle shoals
# Processing Record 3 of Set 13 | antofagasta
# Processing Record 4 of Set 13 | jacmel
# Processing Record 5 of Set 13 | skjervoy
# Processing Record 6 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | zastavna
# Processing Record 8 of Set 13 | sokolka
# Processing Record 9 of Set 13 | urucui
# Processing Record 10 of Set 13 | general pico
# Processing Record 11 of Set 13 | dingzhou
# Processing Record 12 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 13 | garowe
# Processing Record 14 of Set 13 | cartagena
# Processing Record 15 of Set 13 | walvis bay
# Processing Record 16 of Set 13 | kapuskasing
# Processing Record 17 of Set 13 | nanjing
# Processing Record 18 of Set 13 | bloomfield
# Processing Record 19 of Set 13 | douentza
# Processing Record 20 of Set 13 | konstantinovka
# Processing Record 21 of Set 13 | gushikawa
# Processing Record 22 of Set 13 | bolshoy lug
# Processing Record 23 of Set 13 | poyarkovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 576

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Puerto Ayora  -0.7393  -90.3518     79.23        74          70
# 1              Laguna  38.4210 -121.4238     65.68        39           0
# 2                Bako   5.7833   36.5667     68.49        67          61
# 3                Adre  13.4667   22.2000     73.33        14           6
# 4  Sao Felix Do Xingu  -6.6447  -51.9950     76.14        90          71
#
#    Wind Speed Country                 Date
# 0        8.68      EC  2022-02-27 22:00:40
# 1        5.30      US  2022-02-27 22:00:41
# 2        6.20      ET  2022-02-27 22:00:41
# 3       15.52      TD  2022-02-27 22:00:42
# 4        2.42      BR  2022-02-27 22:00:42

# %%
new_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0        Puerto Ayora      EC  2022-02-27 22:00:40  -0.7393  -90.3518
# 1              Laguna      US  2022-02-27 22:00:41  38.4210 -121.4238
# 2                Bako      ET  2022-02-27 22:00:41   5.7833   36.5667
# 3                Adre      TD  2022-02-27 22:00:42  13.4667   22.2000
# 4  Sao Felix Do Xingu      BR  2022-02-27 22:00:42  -6.6447  -51.9950
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     79.23        74          70        8.68
# 1     65.68        39           0        5.30
# 2     68.49        67          61        6.20
# 3     73.33        14           6       15.52
# 4     76.14        90          71        2.42

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
